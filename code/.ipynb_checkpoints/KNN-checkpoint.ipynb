# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv')
print(train.shape,test.shape)
# Out:
# ((7352, 563), (2947, 563))

# %%
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# 0         -0.923527         -0.934724    ...
# 1         -0.957686         -0.943068    ...
# 2         -0.977469         -0.938692    ...
# 3         -0.989302         -0.938692    ...
# 4         -0.990441         -0.942469    ...
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.710304                    -0.112754
# 1                        -0.861499                     0.053477
# 2                        -0.760104                    -0.118559
# 3                        -0.482845                    -0.036788
# 4                        -0.699205                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity
# 0              0.179941             -0.058627        1  STANDING
# 1              0.180289             -0.054317        1  STANDING
# 2              0.180637             -0.049118        1  STANDING
# 3              0.181935             -0.047663        1  STANDING
# 4              0.185151             -0.043892        1  STANDING
#
# [5 rows x 563 columns]

# %%
from sklearn.preprocessing import LabelEncoder

X_train = train.iloc[:,:-2]
Y_train = train['Activity']
le = LabelEncoder()
le.fit(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS','WALKING_UPSTAIRS'] )
Y_train_encoded = le.transform(Y_train)

# %%
X_test = test.iloc[:,:-2]
Y_test = test['Activity']
Y_test_encoded = le.transform(Y_test)

# %% [markdown]
# ## Training model using all features

# %%
knn.fit(X_train,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,knn.predict(X_train))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,knn.predict(X_test))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.984221980413
# K Nearest Neighbors Test Accuracy : 0.900237529691

# %% [markdown]
# ## Selecting no. of neighbors

# %%
test_scores = []
for i in range(1,20):
    kn = KNeighborsClassifier(n_neighbors=i)
    kn.fit(X_train,Y_train_encoded)
    acc = accuracy_score(Y_test_encoded,kn.predict(X_test))
    test_scores.append(acc)

# %%
plt.figure(figsize=(10,7))
plt.xlabel('Neighbors')
plt.ylabel('Accuracy')
plt.scatter(range(1,20),test_scores)
plt.xticks([0,5,10,15,20])
# Out:
# ([<matplotlib.axis.XTick at 0x7f83b5b23950>,
#   <matplotlib.axis.XTick at 0x7f83b5b236d0>,
#   <matplotlib.axis.XTick at 0x7f83b5b391d0>,
#   <matplotlib.axis.XTick at 0x7f83b5b39750>,
#   <matplotlib.axis.XTick at 0x7f83b5b39c10>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# ## Training model with 10 neighbors

# %%
kn = KNeighborsClassifier(n_neighbors=10)
kn.fit(X_train,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,kn.predict(X_train))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,kn.predict(X_test))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.97646898803
# K Nearest Neighbors Test Accuracy : 0.906684764167

# %%
cols = ['angle(X,gravityMean)', 'tGravityAcc-min()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-mean()-X',
        'tBodyAcc-mad()-X']
X_train = train[cols]
X_test = test[cols]
X_train.head()
# Out:
#    angle(X,gravityMean)  tGravityAcc-min()-X  tGravityAcc-mean()-Y  \
# 0             -0.841247             0.977436             -0.140840
# 1             -0.844788             0.984520             -0.141551
# 2             -0.848933             0.986770             -0.142010
# 3             -0.848649             0.986821             -0.143976
# 4             -0.847865             0.987434             -0.148750
#
#    tGravityAcc-mean()-X  tBodyAcc-mad()-X
# 0              0.963396         -0.995112
# 1              0.966561         -0.998807
# 2              0.966878         -0.996520
# 3              0.967615         -0.997099
# 4              0.968224         -0.998321

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,knn.predict(X_train))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,knn.predict(X_test))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.953482045702
# K Nearest Neighbors Test Accuracy : 0.69630132338

# %%
train.describe(include='all')
# Out:
#         tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count         7352.000000        7352.000000        7352.000000
# unique                NaN                NaN                NaN
# top                   NaN                NaN                NaN
# freq                  NaN                NaN                NaN
# mean             0.274488          -0.017695          -0.109141
# std              0.070261           0.040811           0.056635
# min             -1.000000          -1.000000          -1.000000
# 25%              0.262975          -0.024863          -0.120993
# 50%              0.277193          -0.017219          -0.108676
# 75%              0.288461          -0.010783          -0.097794
# max              1.000000           1.000000           1.000000
#
#         tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# count        7352.000000       7352.000000       7352.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean           -0.605438         -0.510938         -0.604754
# std             0.448734          0.502645          0.418687
# min            -1.000000         -0.999873         -1.000000
# 25%            -0.992754         -0.978129         -0.980233
# 50%            -0.946196         -0.851897         -0.859365
# 75%            -0.242813         -0.034231         -0.262415
# max             1.000000          0.916238          1.000000
#
#         tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# count        7352.000000       7352.000000       7352.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean           -0.630512         -0.526907         -0.606150
# std             0.424073          0.485942          0.414122
# min            -1.000000         -1.000000         -1.000000
# 25%            -0.993591         -0.978162         -0.980251
# 50%            -0.950709         -0.857328         -0.857143
# 75%            -0.292680         -0.066701         -0.265671
# max             1.000000          0.967664          1.000000
#
#         tBodyAcc-max()-X    ...     fBodyBodyGyroJerkMag-kurtosis()  \
# count        7352.000000    ...                         7352.000000
# unique               NaN    ...                                 NaN
# top                  NaN    ...                                 NaN
# freq                 NaN    ...                                 NaN
# mean           -0.468604    ...                           -0.625294
# std             0.544547    ...                            0.307584
# min            -1.000000    ...                           -0.999765
# 25%            -0.936219    ...                           -0.845573
# 50%            -0.881637    ...                           -0.711692
# 75%            -0.017129    ...                           -0.503878
# max             1.000000    ...                            0.956845
#
#         angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                   7352.000000                           7352.000000
# unique                          NaN                                   NaN
# top                             NaN                                   NaN
# freq                            NaN                                   NaN
# mean                       0.008684                              0.002186
# std                        0.336787                              0.448306
# min                       -0.976580                             -1.000000
# 25%                       -0.121527                             -0.289549
# 50%                        0.009509                              0.008943
# 75%                        0.150865                              0.292861
# max                        1.000000                              1.000000
#
#         angle(tBodyGyroMean,gravityMean)  \
# count                        7352.000000
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# mean                            0.008726
# std                             0.608303
# min                            -1.000000
# 25%                            -0.482273
# 50%                             0.008735
# 75%                             0.506187
# max                             0.998702
#
#         angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                            7352.000000           7352.000000
# unique                                   NaN                   NaN
# top                                      NaN                   NaN
# freq                                     NaN                   NaN
# mean                               -0.005981             -0.489547
# std                                 0.477975              0.511807
# min                                -1.000000             -1.000000
# 25%                                -0.376341             -0.812065
# 50%                                -0.000368             -0.709417
# 75%                                 0.359368             -0.509079
# max                                 0.996078              1.000000
#
#         angle(Y,gravityMean)  angle(Z,gravityMean)      subject  Activity
# count            7352.000000           7352.000000  7352.000000      7352
# unique                   NaN                   NaN          NaN         6
# top                      NaN                   NaN          NaN    LAYING
# freq                     NaN                   NaN          NaN      1407
# mean                0.058593             -0.056515    17.413085       NaN
# std                 0.297480              0.279122     8.975143       NaN
# min                -1.000000             -1.000000     1.000000       NaN
# 25%                -0.017885             -0.143414     8.000000       NaN
# 50%                 0.182071              0.003181    19.000000       NaN
# 75%                 0.248353              0.107659    26.000000       NaN
# max                 0.478157              1.000000    30.000000       NaN
#
# [11 rows x 563 columns]

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
X_train = train.iloc[:,:-2]
X_test = test.iloc[:,:-2]
pca = PCA(n_components=10)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print(X_train.shape,X_train_pca.shape)
print(X_test.shape,X_test_pca.shape)
# Out:
# ((7352, 561), (7352, 10))
# ((2947, 561), (2947, 10))

# %%
knn = KNeighborsClassifier().fit(X_train_pca,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,knn.predict(X_train_pca))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,knn.predict(X_test_pca))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.939064200218
# K Nearest Neighbors Test Accuracy : 0.84289107567

# %%
r = range(10,251,10)
pca_scores = []
for i in r:
    pca = PCA(n_components=i,random_state=0).fit(X_train)
    X_train_pca = pca.transform(X_train)
    X_test_pca = pca.transform(X_test)
    knn = KNeighborsClassifier().fit(X_train_pca,Y_train_encoded)
    acc = accuracy_score(Y_test_encoded,knn.predict(X_test_pca))
    pca_scores.append(acc)
    print("{} : {}".format(i,acc))
# Out:
# 10 : 0.84289107567
# 20 : 0.859518154055
# 30 : 0.872751951137
# 40 : 0.8768238887
# 50 : 0.884967763828
# 60 : 0.890057685782
# 70 : 0.894468951476
# 80 : 0.894468951476
# 90 : 0.894129623346
# 100 : 0.895486935867
# 110 : 0.89888021717
# 120 : 0.899898201561
# 130 : 0.900576857822
# 140 : 0.901255514082
# 150 : 0.901594842212
# 160 : 0.901934170343
# 170 : 0.902612826603
# 180 : 0.902612826603
# 190 : 0.901594842212
# 200 : 0.900576857822
# 210 : 0.901255514082
# 220 : 0.900237529691
# 230 : 0.900237529691
# 240 : 0.900237529691
# 250 : 0.900916185952

# %%
plt.figure(figsize=(10,10))
plt.xlabel('n_components in PCA')
plt.ylabel('Accuracy')
plt.scatter(range(10,260,10),pca_scores)
plt.xticks(range(10,260,10))
# Out:
# ([<matplotlib.axis.XTick at 0x7f83b57a1c50>,
#   <matplotlib.axis.XTick at 0x7f83b3e014d0>,
#   <matplotlib.axis.XTick at 0x7f83b3d9dfd0>,
#   <matplotlib.axis.XTick at 0x7f83b3d2c450>,
#   <matplotlib.axis.XTick at 0x7f83b3d2c910>,
#   <matplotlib.axis.XTick at 0x7f83b3d2cdd0>,
#   <matplotlib.axis.XTick at 0x7f83b3d362d0>,
#   <matplotlib.axis.XTick at 0x7f83b3d36790>,
#   <matplotlib.axis.XTick at 0x7f83b3d36c50>,
#   <matplotlib.axis.XTick at 0x7f83b3d40150>,
#   <matplotlib.axis.XTick at 0x7f83b3d40610>,
#   <matplotlib.axis.XTick at 0x7f83b3d40ad0>,
#   <matplotlib.axis.XTick at 0x7f83b3d40f90>,
#   <matplotlib.axis.XTick at 0x7f83b3d4a490>,
#   <matplotlib.axis.XTick at 0x7f83b3d4a950>,
#   <matplotlib.axis.XTick at 0x7f83b3d4ae10>,
#   <matplotlib.axis.XTick at 0x7f83b3d55310>,
#   <matplotlib.axis.XTick at 0x7f83b3d557d0>,
#   <matplotlib.axis.XTick at 0x7f83b3d55c90>,
#   <matplotlib.axis.XTick at 0x7f83b3d5f190>,
#   <matplotlib.axis.XTick at 0x7f83b3d5f650>,
#   <matplotlib.axis.XTick at 0x7f83b3d5fb10>,
#   <matplotlib.axis.XTick at 0x7f83b3d5ffd0>,
#   <matplotlib.axis.XTick at 0x7f83b3ceb4d0>,
#   <matplotlib.axis.XTick at 0x7f83b3ceb990>],
#  <a list of 25 Text xticklabel objects>)

# %%
pca = PCA(n_components=170,random_state=0).fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
knn = KNeighborsClassifier().fit(X_train_pca,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,knn.predict(X_train_pca))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,knn.predict(X_test_pca))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.984085963003
# K Nearest Neighbors Test Accuracy : 0.902612826603

# %%
pca_test_scores = []
for i in range(1,20):
    kn = KNeighborsClassifier(n_neighbors=i)
    kn.fit(X_train_pca,Y_train_encoded)
    acc = accuracy_score(Y_test_encoded,kn.predict(X_test_pca))
    pca_test_scores.append(acc)
    print("{} : {}".format(i,acc))
# Out:
# 1 : 0.877502544961
# 2 : 0.866644044791
# 3 : 0.893450967085
# 4 : 0.895486935867
# 5 : 0.902612826603
# 6 : 0.901255514082
# 7 : 0.902273498473
# 8 : 0.905666779776
# 9 : 0.904309467255
# 10 : 0.905666779776
# 11 : 0.903291482864
# 12 : 0.902612826603
# 13 : 0.903630810994
# 14 : 0.906006107906
# 15 : 0.903970139125
# 16 : 0.906345436037
# 17 : 0.908042076688
# 18 : 0.907024092297
# 19 : 0.905327451646

# %%
plt.figure(figsize=(10,7))
plt.xlabel('neighbors in PCA')
plt.ylabel('Accuracy')
plt.scatter(range(1,20),pca_test_scores)
plt.xticks(range(5,21,5))
# Out:
# ([<matplotlib.axis.XTick at 0x7f83b3e7c7d0>,
#   <matplotlib.axis.XTick at 0x7f83b3e34e10>,
#   <matplotlib.axis.XTick at 0x7f83b2f68b10>,
#   <matplotlib.axis.XTick at 0x7f83b2f7c050>],
#  <a list of 4 Text xticklabel objects>)

# %% [markdown]
# ## Training model with 17 neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=17)
knn.fit(X_train_pca,Y_train_encoded)
print ("K Nearest Neighbors Train Accuracy : {}".format(accuracy_score(Y_train_encoded,knn.predict(X_train_pca))))
print ("K Nearest Neighbors Test Accuracy : {}".format(accuracy_score(Y_test_encoded,knn.predict(X_test_pca))))
# Out:
# K Nearest Neighbors Train Accuracy : 0.967763873776
# K Nearest Neighbors Test Accuracy : 0.908042076688
