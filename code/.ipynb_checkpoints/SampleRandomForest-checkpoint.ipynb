# %% [markdown]
# ## 00 . Import packages

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import pandas_profiling as prof

from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 01 . Import data

# %%
from sklearn.utils import shuffle

train = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv')

train = shuffle(train,random_state=20)
test = shuffle(test,random_state=20)

train.head()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2106           0.273972          -0.012957          -0.087069
# 3683           0.263492          -0.028011          -0.069832
# 6032           0.327688          -0.038859          -0.109544
# 5167           0.280753          -0.018152          -0.106467
# 3666           0.253746          -0.004908          -0.078807
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2106         -0.958541         -0.918072         -0.958524         -0.964914
# 3683         -0.991749         -0.851621         -0.912838         -0.993858
# 6032         -0.267388         -0.139810         -0.234038         -0.294866
# 5167         -0.991128         -0.996708         -0.993876         -0.991261
# 3666         -0.975188         -0.973573         -0.928597         -0.976399
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X        ...         \
# 2106         -0.916081         -0.958211         -0.876891        ...
# 3683         -0.854585         -0.905712         -0.929881        ...
# 6032         -0.159947         -0.236933         -0.156880        ...
# 5167         -0.996684         -0.996311         -0.937765        ...
# 3666         -0.971490         -0.919084         -0.924473        ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2106                        -0.182322                    -0.029072
# 3683                        -0.794056                    -0.102711
# 6032                         0.123991                    -0.579474
# 5167                        -0.780155                     0.101561
# 3666                        -0.827178                    -0.024248
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2106                              0.716731                         -0.390390
# 3683                             -0.305741                          0.265990
# 6032                             -0.714091                          0.934828
# 5167                              0.046157                          0.352336
# 3666                             -0.172460                         -0.347837
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2106                             -0.259374             -0.840449
# 3683                             -0.182242              0.588365
# 6032                              0.329317             -0.768093
# 5167                             -0.313949              0.465078
# 3666                              0.396368             -0.549379
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 2106              0.088154             -0.098462       11           SITTING
# 3683             -0.587006             -0.416704       19            LAYING
# 6032              0.224007              0.120465       27  WALKING_UPSTAIRS
# 5167             -0.698623             -0.285552       25            LAYING
# 3666             -0.057849             -0.260573       19           SITTING
#
# [5 rows x 563 columns]

# %%
randomState = 42
ntree = 25

# %% [markdown]
# ## 02.a. Base Random Forest - with all variables

# %%
def varPlot(X,model,plotSize=(15,6),xticks=False):
    
    model_vars = pd.DataFrame(
         {'variable':X.columns,
          'importance':model.feature_importances_})

    model_vars.sort_values(by='importance',
                           ascending=False,
                           inplace=True)
    
    varImp = plt.figure(figsize=plotSize)
    varImp = sns.set_style('whitegrid')

    varImp = sns.barplot(y=model_vars['importance'],
        x=model_vars['variable'],
        palette=sns.color_palette("Blues_r",
                                  n_colors=X.shape[1]))
    
    if xticks==True:
        varImp = plt.xticks([])
    else:
        varImp = plt.xticks(rotation=90)
        
    varImp = plt.xlabel('Variable')
    varImp = plt.ylabel('Variable Importance')
    varImp = plt.title('Random Forest : Averaged variable importance over '+str(ntree)+' trees')
    return(varImp)

# %% [markdown]
# #### Build model containing all 561 variables

# %%
from sklearn.preprocessing import LabelEncoder

# Encode our categorical labels into numerical target labels
le = LabelEncoder()
le = le.fit(["WALKING", "WALKING_UPSTAIRS", "WALKING_DOWNSTAIRS", "SITTING", "STANDING", "LAYING"])

X = train[train.columns[:-2]]
Y = train.Activity
Y = le.transform(Y)

randomState = 42

model0 = rfc(n_estimators=ntree,
             random_state=randomState,
             n_jobs=4,
             warm_start=True,
             oob_score=True)
model0 = model0.fit(X, Y)
model0.oob_score_
# Out:
# 0.971436343852013

# %%
accuracy_score(Y,model0.predict(X))
# Out:
# 1.0

# %%
accuracy_score(le.transform(test['Activity']),model0.predict(test[test.columns[:-2]]))
# Out:
# 0.9175432643366135

# %% [markdown]
# #### Variable importance : all 561 variables

# %%
varPlot(X=X,model=model0,plotSize=(15,6),xticks=True)
# Out:
# Text(0.5,1,u'Random Forest : Averaged variable importance over 25 trees')

# %% [markdown]
# #### Sorted dataframe for variable & their importance score

# %%
model_vars0 = pd.DataFrame(
         {'variable':X.columns,
          'importance':model0.feature_importances_})

model_vars0.sort_values(by='importance',
                           ascending=False,
                           inplace=True)

# %%
model_vars0.head(10)
# Out:
#      importance                           variable
# 558    0.059845               angle(X,gravityMean)
# 41     0.030715               tGravityAcc-mean()-Y
# 52     0.029180                tGravityAcc-min()-X
# 40     0.028755               tGravityAcc-mean()-X
# 49     0.028444                tGravityAcc-max()-X
# 403    0.023977  fBodyAccJerk-bandsEnergy()-1,16.1
# 50     0.023345                tGravityAcc-max()-Y
# 389    0.022747    fBodyAccJerk-bandsEnergy()-1,16
# 559    0.022566               angle(Y,gravityMean)
# 53     0.021540                tGravityAcc-min()-Y

# %% [markdown]
# ## 02.b. top n variables

# %%
n = 25

cols_model = [col for col in model_vars0.variable[:n].values]
print(cols_model)
# Out:
# ['angle(X,gravityMean)', 'tGravityAcc-mean()-Y', 'tGravityAcc-min()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X', 'fBodyAccJerk-bandsEnergy()-1,16.1', 'tGravityAcc-max()-Y', 'fBodyAccJerk-bandsEnergy()-1,16', 'angle(Y,gravityMean)', 'tGravityAcc-min()-Y', 'tGravityAcc-energy()-X', 'tGravityAcc-arCoeff()-Z,1', 'tGravityAcc-arCoeff()-Z,2', 'tBodyAccJerk-std()-X', 'fBodyAccJerk-bandsEnergy()-1,24', 'tGravityAcc-energy()-Y', 'tBodyGyroJerk-iqr()-Z', 'tBodyAccJerk-sma()', 'tGravityAcc-arCoeff()-Z,4', 'fBodyAccMag-mad()', 'tGravityAcc-min()-Z', 'fBodyAccJerk-bandsEnergy()-1,8', 'tGravityAccMag-std()', 'fBodyBodyAccJerkMag-mean()', 'angle(Z,gravityMean)']

# %% [markdown]
# #### Create OOB accuracy table for using top 1 to n variables at a time

# %%
oobAccuracy = {}

for cols in range(n):
    X = train[[col for col in model_vars0['variable'][:cols+1].values]]
    Y = train.Activity
    Y = le.transform(Y)
    
    model1 = rfc(n_estimators=ntree,
                 random_state=randomState,
                 n_jobs=4,
                 warm_start=False,
                 oob_score=True)
    
    model1 = model1.fit(X, Y)
    accuracy = accuracy_score(Y,model1.predict(X))
    
    oobAccuracy[cols+1] = [cols+1,model1.oob_score_,accuracy]

accuracyTable =pd.DataFrame.from_dict(oobAccuracy).transpose()
accuracyTable.columns = ['variables','oobAccuracy','accuracy']

# %%
accuracyTable
# Out:
#     variables  oobAccuracy  accuracy
# 1         1.0     0.430495  0.998776
# 2         2.0     0.725245  1.000000
# 3         3.0     0.864255  1.000000
# 4         4.0     0.872688  1.000000
# 5         5.0     0.884657  1.000000
# 6         6.0     0.937976  1.000000
# 7         7.0     0.942329  1.000000
# 8         8.0     0.949674  1.000000
# 9         9.0     0.948585  1.000000
# 10       10.0     0.951714  1.000000
# 11       11.0     0.952938  1.000000
# 12       12.0     0.955794  1.000000
# 13       13.0     0.954162  1.000000
# 14       14.0     0.956474  1.000000
# 15       15.0     0.956202  1.000000
# 16       16.0     0.953482  1.000000
# 17       17.0     0.955114  1.000000
# 18       18.0     0.959195  1.000000
# 19       19.0     0.957155  1.000000
# 20       20.0     0.967220  1.000000
# 21       21.0     0.973749  1.000000
# 22       22.0     0.973749  1.000000
# 23       23.0     0.973613  1.000000
# 24       24.0     0.975517  1.000000
# 25       25.0     0.977421  1.000000

# %% [markdown]
# #### Plot OOB accuracy vs number of variables

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=accuracyTable.variables,
                y=100*accuracyTable.oobAccuracy)

plt.xlim(0,n+1)
plt.ylim(0,100)
plt.minorticks_on()

plt.xlabel('Number of variables')
plt.ylabel('Accuracy(%)')
plt.title('OOB Accuracy vs Number of variables')
# Out:
# Text(0.5,1,u'OOB Accuracy vs Number of variables')

# %% [markdown]
# #### Variable importance plot for top n variables

# %%
varPlot(X,model1)
# Out:
# Text(0.5,1,u'Random Forest : Averaged variable importance over 145 trees')

# %% [markdown]
# ## 02.c. Selected variables (5) from top 15

# %%
n_used = 6

cols_model = [col for col in model_vars0.variable[:n_used].values]
print(cols_model)
# Out:
# ['angle(X,gravityMean)', 'tGravityAcc-mean()-Y', 'tGravityAcc-min()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X', 'fBodyAccJerk-bandsEnergy()-1,16.1']

# %%
X = train[cols_model]
Y = train.Activity
Y = le.transform(Y)

# %% [markdown]
# #### For the selected variables, we determine optimum number of trees
#
#  - Create a loop for 5 to 150 trees with steps of 5
#
#  - Fit a model during each iteration
#
#  - Store OOB score for each iteration

# %%
ntree_determination = {}

for ntree in range(5,150,5):
    model = rfc(n_estimators=ntree,
             random_state=randomState,
             n_jobs=4,
             warm_start=False,
             oob_score=True)
    model = model.fit(X, Y)
    ntree_determination[ntree]=model.oob_score_

# %%
ntree_determination
# Out:
# {5: 0.809575625680087,
#  10: 0.8947225244831338,
#  15: 0.9152611534276387,
#  20: 0.9239662676822633,
#  25: 0.926822633297062,
#  30: 0.9317192600652884,
#  35: 0.9328073993471164,
#  40: 0.9328073993471164,
#  45: 0.9336235038084875,
#  50: 0.9328073993471164,
#  55: 0.933759521218716,
#  60: 0.9341675734494015,
#  65: 0.9352557127312296,
#  70: 0.9362078346028292,
#  75: 0.9362078346028292,
#  80: 0.9363438520130577,
#  85: 0.9372959738846572,
#  90: 0.9382480957562568,
#  95: 0.9371599564744287,
#  100: 0.9374319912948857,
#  105: 0.9377040261153428,
#  110: 0.9377040261153428,
#  115: 0.9375680087051143,
#  120: 0.9381120783460283,
#  125: 0.9375680087051143,
#  130: 0.9372959738846572,
#  135: 0.9379760609357998,
#  140: 0.9370239390642002,
#  145: 0.9379760609357998}

# %%
ntree_determination = pd.DataFrame.from_dict(ntree_determination,orient='index')
ntree_determination['ntree'] = ntree_determination.index
ntree_determination.columns=['oobScore','ntree']

# %%
ntree_determination.head(10)
# Out:
#      oobScore  ntree
# 130  0.937296    130
# 5    0.809576      5
# 135  0.937976    135
# 10   0.894723     10
# 140  0.937024    140
# 15   0.915261     15
# 145  0.937976    145
# 20   0.923966     20
# 25   0.926823     25
# 30   0.931719     30

# %% [markdown]
# #### Plot number of trees vs OOB accuracy

# %%
plt.figure(figsize=(15,5))

plt.scatter(x='ntree',
                y='oobScore',
                s=35,c='red',alpha=0.65,
                data=ntree_determination)
plt.xlabel('Number of trees used')
plt.ylabel('OOB Accuracy')
# Out:
# Text(0,0.5,u'OOB Accuracy')

# %% [markdown]
# #### For our final iteration, we choose 50 trees & 5 variables

# %%
model2 = rfc(n_estimators=50,
             random_state=randomState,
             n_jobs=4,
             warm_start=False,
             oob_score=True)
model2 = model2.fit(X, Y)

# %% [markdown]
# #### Variable importance plot for the final model

# %%
varPlot(X,model2,plotSize=(6,4))
# Out:
# Text(0.5,1,u'Random Forest : Averaged variable importance over 145 trees')

# %% [markdown]
# ### Accuracy metrics for the final model

# %%
train_actual = Y
train_pred = model2.predict(X)

# %% [markdown]
# #### Confusion matrix for training data

# %%
confusion_matrix(train_actual,train_pred)
# Out:
# array([[1407,    0,    0,    0,    0,    0],
#        [   0, 1286,    0,    0,    0,    0],
#        [   0,    1, 1373,    0,    0,    0],
#        [   0,    0,    0, 1226,    0,    0],
#        [   0,    0,    0,    0,  985,    1],
#        [   0,    0,    0,    0,    0, 1073]])

# %%
sns.heatmap(data=confusion_matrix(train_actual,train_pred),
            fmt='.0f',
            annot=True,
            xticklabels=np.unique(train_actual),
            yticklabels=np.unique(train_actual))

# %% [markdown]
# #### Training accuracy

# %%
accuracy_score(train_actual,train_pred)
# Out:
# 0.999727965179543

# %% [markdown]
# #### OOB accuracy

# %%
model2.oob_score_
# Out:
# 0.9328073993471164

# %% [markdown]
# ## 4. Test set results

# %%
test_actual = test.Activity
test_actual = le.transform(test_actual)
test_pred = model2.predict(test[X.columns])

# %% [markdown]
# #### Confusion matrix for test data

# %%
confusion_matrix(test_actual,test_pred)
# Out:
# array([[537,   0,   0,   0,   0,   0],
#        [  0, 360, 129,   0,   0,   2],
#        [  0, 110, 421,   0,   1,   0],
#        [  0,   0,   0, 295,  90, 111],
#        [  0,   0,   0, 102, 253,  65],
#        [  0,   0,   2,  91,  83, 295]])

# %%
sns.heatmap(data=confusion_matrix(test_actual,test_pred),
            fmt='.0f',
            annot=True,
            xticklabels=np.unique(test_actual),
            yticklabels=np.unique(test_actual))

# %% [markdown]
# #### Accuracy on test data

# %%
accuracy_score(test_actual,test_pred)
# Out:
# 0.7332880895826264

# %% [markdown]
# #### Distribution of final variables for each category

# %%
plt.figure(figsize=(6,6))
sns.set_style('whitegrid')

sns.pairplot(data=train[[col for col in X.columns]+['Activity']],
             hue='Activity',
             palette='Set2',
             diag_kind='kde')
